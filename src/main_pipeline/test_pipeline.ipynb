# %%
from pipeline import Pipeline

# Claim

# Run Pipeline
pipeline = Pipeline()
# Out:
# Loaded 527 relations and their embeddings from D:\\claimpkg\\claimpkg-clone\\src\\resources\\embeddings.
# Loaded 1591850 entities and their embeddings from D:\\claimpkg\\claimpkg-clone\\src\\resources\\embeddings.

# %%
TEST_CASE = [
    # EASY CASES
    {
        "claim": "NASA là cơ quan hàng không của Việt Nam",
        "verdict": "Refuted",
        "explanation": "NASA is the United States' space agency, not Vietnam's.",
    },
    {
        "claim": "Bạn biết bộ phim Người đẹp và Quái vật chứ?",
        "verdict": "Unsupported",
        "explanation": "Refuse to answer as the claim is not a valid claim.",
    },
    {
        "claim": "The Eiffel Tower is located in Berlin.",
        "verdict": "Refuted",
        "explanation": "The Eiffel Tower is located in Paris, not Berlin.",
    },
    {
        "claim": "日本語は日本の言語です。",
        "verdict": "Supported",
        "explanation": "Japanese is the language of Japan.",
    },
    {
        "claim": "There are some days in Moscow that the sun does not rise.",
        "verdict": "Refuted",
        "explanation": "Moskow is located at a latitude of 55.75N where the sun rises every day of the year.",
        # This one expected to be failed, due to cannot infer during the
    },

    # MEDIUM CASES (WITH 1 MISSING ENTITIES)
    {
        "claim": "Nhà Nguyễn đóng đô tại một thành phố ở phía Bắc thành phố Đà Nẵng.",
        "verdict": "Supported",
        "explanation": "The Nguyễn dynasty was established in Hue, a city north of Da Nang.",
    },
    {
        "claim": "Cadillac CT6 và Stranger Things series có cùng năm ra đời.",
        "verdict": "Supported",
        "explanation": "Both Cadillac CT6 and the Stranger Things series were first released in 2016.",
    },
    {
        "claim": "Both Sevilla FC and FC Barcelona are football that participate in at least a same League.",
        "verdict": "Supported",
        "explanation": "Both Sevilla FC and FC Barcelona participate in La Liga.",
    },
    {
        "claim": "Hòa Bình Province is in the southwest of the city that led by Ngô Thị Doãn Thanh, established by the Nguyễn dynasty and nicknamed 'Affluence'.",
        "verdict": "Refuted",
        "explanation": "Hòa Bình Province is right southwest of Hanoi, which is led by Ngô Thị Doãn Thanh, but Hue is established by the Nguyễn dynasty and Phú Thọ province nicknamed 'Affluence.'",
    },
    {
        "claim": "Thủ đô của Việt Nam nằm ở phía Bắc.",
        "verdict": "Supported",
        "explanation": "Vietnam's capital, Hanoi, is located in the northern part of the country.",
    },

    # HARD CASES
    {
        # This one testing dimensional reasoning
        "claim": "There are two provinces that located in the middle of Nghệ An and Quảng Trị.",
        "verdict": "Supported",
        "explanation": "Hà Tĩnh Province is located south of Nghệ An Province, and Quảng Bình Province is located north of Quảng Trị Province. Therefore, there are two provinces (Hà Tĩnh and Quảng Bình) located between Nghệ An and Quảng Trị.",
    },
    {
        "claim": "Ho Chi Minh City had some districts that marked with numbers.",
        "verdict": "Supported",
        "explanation": "Hà Tĩnh Province is located south of Nghệ An Province, and Quảng Bình Province is located north of Quảng Trị Province. Therefore, there are two provinces (Hà Tĩnh and Quảng Bình) located between Nghệ An and Quảng Trị.",
    },
    {
        "claim": "There is at least one state in the USA that has the name starts with an 'L'",
        "verdict": "Supported",
        "explanation": "Louisiana is a state in the USA that starts with the letter 'L'.",
    },
    {
        "claim": "Ho Chi Minh City has an international airport that has a runway length over 3000m.",
        "verdict": "Supported",
        "explanation": "Long Thanh International Airport served Ho Chi Minh City has a runway length of 4000m, which is over 3000m.",
    },
    {
        "claim": "Melania Trump not a child of an American Republican member.",
        "verdict": "Refuted",
        "explanation": "Melania Trump is the child of Donald Trump, who is a member of the American Republican Party.",
    }
]

# %%
claim = "There are two provinces that located in the middle of Nghệ An and Quảng Trị."

final_answer = pipeline.run(claim=claim, specialize_mode="FEWSHOT", retry=3)
print(final_answer)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# RES: <e>unknown_0</e> || locatedBetween || <e>Nghệ An</e>
# <e>unknown_0</e> || locatedBetween || <e>Quảng Trị</e>
# <e>unknown_1</e> || locatedBetween || <e>Nghệ An</e>
# <e>unknown_1</e> || locatedBetween || <e>Quảng Trị</e>
# <e>Nghệ An</e> || adjacentTo || <e>unknown_0</e>
# <e>unknown_0</e> || adjacentTo || <e>unknown_1</e>
# <e>unknown_1</e> || adjacentTo || <e>Quảng Trị</e>
# <e>unknown_0</e> || instanceOf || <e>Province</e>
# <e>unknown_1</e> || instanceOf || <e>Province</e>
# Generated Pseudo Graph Triplets:
# <e>unknown_0</e> || locatedBetween || <e>Nghệ An</e>
# <e>unknown_0</e> || locatedBetween || <e>Quảng Trị</e>
# <e>unknown_1</e> || locatedBetween || <e>Nghệ An</e>
# <e>unknown_1</e> || locatedBetween || <e>Quảng Trị</e>
# <e>Nghệ An</e> || adjacentTo || <e>unknown_0</e>
# <e>unknown_0</e> || adjacentTo || <e>unknown_1</e>
# <e>unknown_1</e> || adjacentTo || <e>Quảng Trị</e>
# <e>unknown_0</e> || instanceOf || <e>Province</e>
# <e>unknown_1</e> || instanceOf || <e>Province</e>
# Normalized Triplets:
#  [{'head': 'unknown_0', 'relation': 'place', 'tail': 'Nghệ An Province'}, {'head': 'unknown_0', 'relation': 'place', 'tail': 'Quảng Trị Province'}, {'head': 'unknown_1', 'relation': 'place', 'tail': 'Nghệ An Province'}, {'head': 'unknown_1', 'relation': 'place', 'tail': 'Quảng Trị Province'}, {'head': 'Nghệ An Province', 'relation': 'neighboringMunicipalities', 'tail': 'unknown_0'}, {'head': 'unknown_0', 'relation': 'neighboringMunicipalities', 'tail': 'unknown_1'}, {'head': 'unknown_1', 'relation': 'neighboringMunicipalities', 'tail': 'Quảng Trị Province'}, {'head': 'unknown_0', 'relation': 'placeOfDeath', 'tail': 'Province'}, {'head': 'unknown_1', 'relation': 'placeOfDeath', 'tail': 'Province'}]
# KG adjacency built. {'Province': {}, 'Quảng Trị Province': {}, 'Nghệ An Province': {}}
# Grouped and Decomposed Triplets:
# {'complete_triplets': [], 'incomplete_groups': {'unknown_0': {'unknown': 'unknown_0', 'explicit_entities': ['Nghệ An Province', 'Quảng Trị Province', 'Nghệ An Province', 'unknown_1', 'Province'], 'relations': ['place', 'place', 'neighboringMunicipalities', 'neighboringMunicipalities', 'placeOfDeath'], 'raw_triplets': [{'head': 'unknown_0', 'relation': 'place', 'tail': 'Nghệ An Province'}, {'head': 'unknown_0', 'relation': 'place', 'tail': 'Quảng Trị Province'}, {'head': 'Nghệ An Province', 'relation': 'neighboringMunicipalities', 'tail': 'unknown_0'}, {'head': 'unknown_0', 'relation': 'neighboringMunicipalities', 'tail': 'unknown_1'}, {'head': 'unknown_0', 'relation': 'placeOfDeath', 'tail': 'Province'}]}, 'unknown_1': {'unknown': 'unknown_1', 'explicit_entities': ['Nghệ An Province', 'Quảng Trị Province', 'Quảng Trị Province', 'Province'], 'relations': ['place', 'place', 'neighboringMunicipalities', 'placeOfDeath'], 'raw_triplets': [{'head': 'unknown_1', 'relation': 'place', 'tail': 'Nghệ An Province'}, {'head': 'unknown_1', 'relation': 'place', 'tail': 'Quảng Trị Province'}, {'head': 'unknown_1', 'relation': 'neighboringMunicipalities', 'tail': 'Quảng Trị Province'}, {'head': 'unknown_1', 'relation': 'placeOfDeath', 'tail': 'Province'}]}}}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 claim = "There are two provinces that located in the middle of Nghệ An and Quảng Trị."
# ----> 3 final_answer = pipeline.run(claim=claim, specialize_mode="FEWSHOT", retry=3)
#       4 print(final_answer)
#
# File d:\claimpkg\claimpkg-clone\src\main_pipeline\pipeline.py:87, in Pipeline.run(self, claim, specialize_mode, retry)
#      84     return final_answer
#      86 # This is the final step if the final answer is NotEnoughInfo, use greedy query to query all related entities and relations
# ---> 87 greedy_real_graph = self.greedy.greedy(triplets=parsed, k_relations=3)
#      88 final_answer = self.general_llm.submit(claim=claim, graph_string=greedy_real_graph, max_tokens=8192)
#      90 return final_answer
#
# File d:\claimpkg\claimpkg-clone\src\main_pipeline\..\middle\greedy.py:72, in Greedy.greedy(self, triplets, k_relations)
#      70 relation_candidates : Dict[str, List[str]] = dict()
#      71 for rel in relations:
# ---> 72     relation_candidates[rel] = self.sim.get_candidate_relations(raw_relation=rel, top_k=k_relations)
#      73 # Map back to entity_to_rel
#      74 for entity, rel_list in entity_to_rel.items():
#
# File d:\claimpkg\claimpkg-clone\src\main_pipeline\..\utils\sim.py:245, in Similarity.get_candidate_relations(self, raw_relation, top_k)
#     244 def get_candidate_relations(self, raw_relation: str, top_k: int = 5):
# --> 245     return self.match_embed(raw_relation, self.kg_relations, self.relation_embeddings, top_k=top_k)
#
# File d:\claimpkg\claimpkg-clone\src\main_pipeline\..\utils\sim.py:240, in Similarity.match_embed(self, raw, reference, reference_embeddings, top_k)
#     238 def match_embed(self, raw: str, reference, reference_embeddings, top_k: int):
#     239     emb = self.encoder.encode([raw], normalize_embeddings=True)[0]
# --> 240     scores = reference_embeddings @ emb
#     241     top_k_indices = torch.topk(torch.tensor(scores), top_k).indices.tolist()
#     242     return [(reference[i], scores[i].item()) for i in top_k_indices]
#
# ValueError: matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
