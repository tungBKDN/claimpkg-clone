# %%
from pipeline import Pipeline

# Claim

# Run Pipeline
pipeline = Pipeline()
# Out:
# Loaded 527 relations and their embeddings from D:\\claimpkg\\claimpkg-clone\\src\\resources\\embeddings.
# Loaded 1591850 entities and their embeddings from D:\\claimpkg\\claimpkg-clone\\src\\resources\\embeddings.

# %%
TEST_CASE = [
    # EASY CASES
    {
        "claim": "NASA là cơ quan hàng không của Việt Nam",
        "verdict": "Refuted",
    },
    {
        "claim": "Bạn biết bộ phim Người đẹp và Quái vật chứ?",
        "verdict": "Unsupported",
    },
    {
        "claim": "The Eiffel Tower is located in Berlin.",
        "verdict": "Refuted",
    },
    {
        "claim": "日本語は日本の言語です。",
        "verdict": "Supported",
    },

    # MEDIUM CASES (WITH 1 MISSING ENTITIES)
    {
        "claim": "Nhà Nguyễn đóng đô tại một thành phố ở phía Bắc thành phố Đà Nẵng.",
        "verdict": "Supported",
    },
    {
        "claim": "Cadillac CT6 và Stranger Things series có cùng năm ra đời.",
        "verdict": "Supported",
    },
    {
        "claim": "Both Sevilla FC and FC Barcelona are football that participate in at least a same League.",
        "verdict": "Supported",
    }
]

# %%
claim = "Cadillac CT6 và Stranger Things series có cùng năm ra đời."

final_answer = pipeline.run(claim=claim, specialize_mode="FEWSHOT", retry=3)
print(final_answer)
# Out:
# RES: <e>Cadillac CT6</e> || yearOfOrigin || <e>unknown_0</e>
# <e>Stranger Things</e> || yearOfOrigin || <e>unknown_0</e>
# Generated Pseudo Graph Triplets:
# <e>Cadillac CT6</e> || yearOfOrigin || <e>unknown_0</e>
# <e>Stranger Things</e> || yearOfOrigin || <e>unknown_0</e>
# Normalized Triplets:
#  [{'head': 'Cadillac CT6', 'relation': 'stateOfOrigin', 'tail': 'unknown_0'}, {'head': 'Stranger Things (TV series)', 'relation': 'stateOfOrigin', 'tail': 'unknown_0'}]
# KG adjacency built. {'Stranger Things (TV series)': {}, 'Cadillac CT6': {}}
# Grouped and Decomposed Triplets:
# {'complete_triplets': [], 'incomplete_groups': {'unknown_0': {'unknown': 'unknown_0', 'explicit_entities': ['Cadillac CT6', 'Stranger Things (TV series)'], 'relations': ['stateOfOrigin', 'stateOfOrigin'], 'raw_triplets': [{'head': 'Cadillac CT6', 'relation': 'stateOfOrigin', 'tail': 'unknown_0'}, {'head': 'Stranger Things (TV series)', 'relation': 'stateOfOrigin', 'tail': 'unknown_0'}]}}}
#
# With relation [{'triplets': ['<e>Cadillac CT6</e>||modelYears||<e>"2016"</e>', '<e>Cadillac CT6</e>||modelStartYear||<e>"2016"</e>', '<e>Cadillac CT6</e>||productionEndYear||<e>"2015"</e>', '<e>Cadillac CT6</e>||productionStartYear||<e>"2015"</e>', '<e>Cadillac CT6</e>||layout||<e>Front-engine, rear-wheel-drive layout</e>', '<e>Cadillac CT6</e>||assembly||<e>Detroit</e>'], 'candidate_nodes_after_top_k': ['"2016"', 'Front-engine, rear-wheel-drive layout', '"2015"', 'Detroit'], 'explicit_nodes': ['Cadillac CT6', 'Stranger Things (TV series)']}]
#
# Without relation []
# {'verdict': 'NotEnoughInfo', 'explanation': "The evidence provides information about Cadillac CT6's production and model years, but lacks information about the release year of the Stranger Things series, making it impossible to verify the claim.", 'final_graph': '<e>Cadillac CT6</e>||modelYears||<e>"2016"</e>\n<e>Cadillac CT6</e>||modelStartYear||<e>"2016"</e>\n<e>Cadillac CT6</e>||productionEndYear||<e>"2015"</e>\n<e>Cadillac CT6</e>||productionStartYear||<e>"2015"</e>\n<e>Cadillac CT6</e>||layout||<e>Front-engine, rear-wheel-drive layout</e>\n<e>Cadillac CT6</e>||assembly||<e>Detroit</e>'}
