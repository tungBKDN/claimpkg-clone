# %%
from pipeline import Pipeline

# Claim

# Run Pipeline
pipeline = Pipeline()
# Out:
# Loaded 527 relations and their embeddings from D:\\claimpkg\\claimpkg-clone\\src\\resources\\embeddings.
# Loaded 1591850 entities and their embeddings from D:\\claimpkg\\claimpkg-clone\\src\\resources\\embeddings.

# %%
TEST_CASE = [
    # EASY CASES
    {
        "claim": "NASA là cơ quan hàng không của Việt Nam",
        "verdict": "Refuted",
        "explanation": "NASA is the United States' space agency, not Vietnam's.",
    },
    {
        "claim": "Bạn biết bộ phim Người đẹp và Quái vật chứ?",
        "verdict": "Unsupported",
        "explanation": "Refuse to answer as the claim is not a valid claim.",
    },
    {
        "claim": "The Eiffel Tower is located in Berlin.",
        "verdict": "Refuted",
        "explanation": "The Eiffel Tower is located in Paris, not Berlin.",
    },
    {
        "claim": "日本語は日本の言語です。",
        "verdict": "Supported",
        "explanation": "Japanese is the language of Japan.",
    },
    {
        "claim": "There are some days in Moscow that the sun does not rise.",
        "verdict": "Refuted",
        "explanation": "Moskow is located at a latitude of 55.75N where the sun rises every day of the year.",
        # This one expected to be failed, due to cannot infer during the
    },

    # MEDIUM CASES (WITH 1 MISSING ENTITIES)
    {
        "claim": "Nhà Nguyễn đóng đô tại một thành phố ở phía Bắc thành phố Đà Nẵng.",
        "verdict": "Supported",
        "explanation": "The Nguyễn dynasty was established in Hue, a city north of Da Nang.",
    },
    {
        "claim": "Cadillac CT6 và Stranger Things series có cùng năm ra đời.",
        "verdict": "Supported",
        "explanation": "Both Cadillac CT6 and the Stranger Things series were first released in 2016.",
    },
    {
        "claim": "Both Sevilla FC and FC Barcelona are football that participate in at least a same League.",
        "verdict": "Supported",
        "explanation": "Both Sevilla FC and FC Barcelona participate in La Liga.",
    },
    {
        "claim": "Hòa Bình Province is in the southwest of the city that led by Ngô Thị Doãn Thanh, established by the Nguyễn dynasty and nicknamed 'Affluence'.",
        "verdict": "Refuted",
        "explanation": "Hòa Bình Province is right southwest of Hanoi, which is led by Ngô Thị Doãn Thanh, but Hue is established by the Nguyễn dynasty and Phú Thọ province nicknamed 'Affluence.'",
    },
    {
        "claim": "Thủ đô của Việt Nam nằm ở phía Bắc.",
        "verdict": "Supported",
        "explanation": "Vietnam's capital, Hanoi, is located in the northern part of the country.",
    },

    # HARD CASES
    {
        # This one testing dimensional reasoning
        "claim": "There are two provinces that located in the middle of Nghệ An and Quảng Trị.",
        "verdict": "Supported",
        "explanation": "Hà Tĩnh Province is located south of Nghệ An Province, and Quảng Bình Province is located north of Quảng Trị Province. Therefore, there are two provinces (Hà Tĩnh and Quảng Bình) located between Nghệ An and Quảng Trị.",
    },
    {
        "claim": "Ho Chi Minh City had some districts that marked with numbers.",
        "verdict": "Supported",
        "explanation": "Hà Tĩnh Province is located south of Nghệ An Province, and Quảng Bình Province is located north of Quảng Trị Province. Therefore, there are two provinces (Hà Tĩnh and Quảng Bình) located between Nghệ An and Quảng Trị.",
    },
    {
        "claim": "There is at least one state in the USA that has the name starts with an 'L'",
        "verdict": "Supported",
        "explanation": "Louisiana is a state in the USA that starts with the letter 'L'.",
    },
    {
        "claim": "Ho Chi Minh City has an international airport that has a runway length over 3000m.",
        "verdict": "Supported",
        "explanation": "Long Thanh International Airport served Ho Chi Minh City has a runway length of 4000m, which is over 3000m.",
    },
    {
        "claim": "Melania Trump not a child of an American Republican member.",
        "verdict": "Refuted",
        "explanation": "Melania Trump is the child of Donald Trump, who is a member of the American Republican Party.",
    }
]

# %%
claim = "Ho Chi Minh City has an international airport that has a runway length over 3000m."

final_answer = pipeline.run(claim=claim, specialize_mode="FEWSHOT", retry=3)
print(final_answer)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# RES: <e>Ho Chi Minh City</e> || hasAirport || <e>unknown_0</e>
# <e>unknown_0</e> || typeOf || <e>International Airport</e>
# <e>unknown_0</e> || runwayLength || <e>unknown_1</e>
# <e>unknown_1</e> || greaterThan || <e>3000m</e>
# Generated Pseudo Graph Triplets:
# <e>Ho Chi Minh City</e> || hasAirport || <e>unknown_0</e>
# <e>unknown_0</e> || typeOf || <e>International Airport</e>
# <e>unknown_0</e> || runwayLength || <e>unknown_1</e>
# <e>unknown_1</e> || greaterThan || <e>3000m</e>
# Normalized Triplets:
#  [{'head': 'Ho Chi Minh City', 'relation': 'hubAirport', 'tail': 'unknown_0'}, {'head': 'unknown_0', 'relation': 'type', 'tail': 'Flight International'}, {'head': 'unknown_0', 'relation': 'runwayLength', 'tail': 'unknown_1'}, {'head': 'unknown_1', 'relation': 'higher', 'tail': '"300000"'}]
# KG adjacency built. {'"300000"': {}, 'Ho Chi Minh City': {}, 'Flight International': {}}
# Grouped and Decomposed Triplets:
# {'complete_triplets': [], 'incomplete_groups': {'unknown_0': {'unknown': 'unknown_0', 'explicit_entities': ['Ho Chi Minh City', 'Flight International', 'unknown_1'], 'relations': ['hubAirport', 'type', 'runwayLength'], 'raw_triplets': [{'head': 'Ho Chi Minh City', 'relation': 'hubAirport', 'tail': 'unknown_0'}, {'head': 'unknown_0', 'relation': 'type', 'tail': 'Flight International'}, {'head': 'unknown_0', 'relation': 'runwayLength', 'tail': 'unknown_1'}]}, 'unknown_1': {'unknown': 'unknown_1', 'explicit_entities': ['"300000"'], 'relations': ['higher'], 'raw_triplets': [{'head': 'unknown_1', 'relation': 'higher', 'tail': '"300000"'}]}}}
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 claim = "Ho Chi Minh City has an international airport that has a runway length over 3000m."
# ----> 3 final_answer = pipeline.run(claim=claim, specialize_mode="FEWSHOT", retry=3)
#       4 print(final_answer)
#
# File d:\claimpkg\claimpkg-clone\src\main_pipeline\pipeline.py:78, in Pipeline.run(self, claim, specialize_mode, retry)
#      75 for triplet in unified_triplets:
#      76     final_retrieved_triplets += triplet["triplet_as_string"] + "\n"
# ---> 78 final_answer = self.general_llm.submit(claim=claim, graph_string=final_retrieved_triplets)
#      79 # if not final_answer["verdict"] == "NotEnoughInfo":
#      80 #     return final_answer
#      81
#      82 # # This is the final step if the final answer is NotEnoughInfo, use greedy query to query all related entities and relations
#      83 # greedy_real_graph = self.greedy.greedy(standardized_triplets=parsed, greedy_level=2)
#      84 # final_answer = self.general_llm.submit(claim=claim, graph_string=greedy_real_graph, max_tokens=8192)
#      86 return final_answer
#
# File d:\claimpkg\claimpkg-clone\src\main_pipeline\..\llm\general_llm.py:28, in GeneralLLM.submit(self, claim, graph_string, max_tokens)
#      11     def submit(self, claim: str, graph_string: str, max_tokens: int = 2048) -> dict:
#      12         # Tạo prompt đúng định dạng trong paper ClaimPKG
#      13         prompt = f"""
#      14                     Claim: {claim}
#      15
#    (...)
#      26                     - Start with {{ and end with }}.
#      27                     """
# ---> 28         response = self.client.models.generate_content(
#      29             model="gemini-2.0-flash",
#      30             contents=prompt,
#      31             config=types.GenerateContentConfig(
#      32                 temperature=0.3,
#      33                 max_output_tokens=max_tokens,
#      34                 system_instruction="""You are a fact checker. You are going to receive a claim, and evidence as a graph in text format of triples. You need to determine whether the claim is supported by the evidence, refuted by the evidence, or there is not enough information in the evidence to determine whether the claim is true or false. If a relationship has prefix of ~, it means the negation of that relationship. You should answer with one of [Supported, Refuted, NotEnoughInfo] and give a short explanation in one sentence. The output must be in the format: of JSON object like this:
#      35 {{"verdict": "Supported/Refuted/NotEnoughInfo", "explanation": "your explanation here"}}.
#      36                 - Do not add any extra text outside the JSON object like ``` or ```json.
#      37                 - Start with { and end with }.
#      38                 """
#      39             )
#      40         )
#      42         if not response or not response.text:
#      43             raise ValueError("No response from the LLM model.")
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\google\genai\models.py:5020, in Models.generate_content(self, model, contents, config)
#    5018 while remaining_remote_calls_afc > 0:
#    5019   i += 1
# -> 5020   response = self._generate_content(
#    5021       model=model, contents=contents, config=parsed_config
#    5022   )
#    5024   function_map = _extra_utils.get_function_map(parsed_config)
#    5025   if not function_map:
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\google\genai\models.py:3832, in Models._generate_content(self, model, contents, config)
#    3829 request_dict = _common.convert_to_dict(request_dict)
#    3830 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3832 response = self._api_client.request(
#    3833     'post', path, request_dict, http_options
#    3834 )
#    3836 if config is not None and getattr(
#    3837     config, 'should_return_http_response', None
#    3838 ):
#    3839   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\google\genai\_api_client.py:1331, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1321 def request(
#    1322     self,
#    1323     http_method: str,
#    (...)
#    1326     http_options: Optional[HttpOptionsOrDict] = None,
#    1327 ) -> SdkHttpResponse:
#    1328   http_request = self._build_request(
#    1329       http_method, path, request_dict, http_options
#    1330   )
# -> 1331   response = self._request(http_request, http_options, stream=False)
#    1332   response_body = (
#    1333       response.response_stream[0] if response.response_stream else ''
#    1334   )
#    1335   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\google\genai\_api_client.py:1167, in BaseApiClient._request(self, http_request, http_options, stream)
#    1164     retry = tenacity.Retrying(**retry_kwargs)
#    1165     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1167 return self._retry(self._request_once, http_request, stream)
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\AppData\Local\Programs\Python\Python39\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\google\genai\_api_client.py:1144, in BaseApiClient._request_once(self, http_request, stream)
#    1136 else:
#    1137   response = self._httpx_client.request(
#    1138       method=http_request.method,
#    1139       url=http_request.url,
#    (...)
#    1142       timeout=http_request.timeout,
#    1143   )
# -> 1144   errors.APIError.raise_for_response(response)
#    1145   return HttpResponse(
#    1146       response.headers, response if stream else [response.text]
#    1147   )
#
# File d:\claimpkg\claimpkg-clone\.venv\lib\site-packages\google\genai\errors.py:108, in APIError.raise_for_response(cls, response)
#     106 status_code = response.status_code
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#     110   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash\nPlease retry in 22.011287719s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '22s'}]}}
