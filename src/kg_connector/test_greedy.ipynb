# %%
from kg_connector import KGConnector

kg_connector = KGConnector()

# %%
from math import e


entities = kg_connector.get_children_up_to_k(entities=["Ho Chi Minh City"], k=1)
entities
# Out:
# {'Ho Chi Minh City',
#  'Ford Edge',
#  'Adolf Hitler',
#  'Spain national under-20 football team',
#  'KATW',
#  'Rhodesian Armoured Corps',
#  'Chief of the Defence Staff (Canada)',
#  'H2O: Just Add Water',
#  '"LON"',
#  'Jeep Comanche',
#  'AMC Gremlin',
#  'Till Nowak',
#  'Bush Bucks F.C. (1957)',
#  'East Germany',
#  'Pierre Brossolette',
#  'Grigore Moisil National College of Computer Science (Brașov)',
#  'Mary Beth Decker',
#  'Top Gear (2002 TV series)',
#  'Amor de barrio',
#  'The Voice Brasil',
#  'Mitsubishi Delica',
#  'Malden Catholic High School',
#  'Derby of the North (Netherlands)',
#  'Cucumber (TV series)',
#  'Blake Edwards',
#  'Unorganized North Cochrane District',
#  'Toyota Corolla (E170)',
#  'TSN Hockey',
#  'Spain national under-15 football team',
#  'Alfa Romeo Giulia',
#  'Canada national football junior team',
#  'City of Brussels',
#  'Republic of Vietnam National Police Field Force',
#  'The Alan Titchmarsh Show',
#  'Nissan 300ZX',
# ...

# %%
greedy_triplets = kg_connector.get_relations_between(entities=list(entities))
greedy_triplets
# Out:
# '<e>County of Buren</e> || nativeName || <e>"\'\'"</e>\n<e>Cessna T-37 Tweet</e> || aircraftTrainer || <e>Vietnam Air Force</e>\n<e>The Famous Five (1970s TV series)</e> || related || <e>"\'\'"</e>\n<e>Chevrolet Celebrity</e> || engine || <e>"\'\'"</e>\n<e>The Penny Dreadfuls</e> || notableWork || <e>"\'\'"</e>\n<e>City of Brussels</e> || nativeName || <e>"\'\'"</e>\n<e>Persona 2: Eternal Punishment</e> || series || <e>"\'\'"</e>\n<e>Azerbaijan national beach soccer team</e> || nickname || <e>"\'\'"</e>\n<e>Roland Scholl</e> || employer || <e>"\'\'"</e>\n<e>KZSJ</e> || alias || <e>"\'\'"</e>\n<e>Unorganized Kenora District</e> || north || <e>"\'\'"</e>\n<e>Unorganized Kenora District</e> || southwest || <e>Rat Portage 38A, Ontario</e>\n<e>Unorganized Kenora District</e> || southwest || <e>"\'\'"</e>\n<e>Unorganized Kenora District</e> || southeast || <e>Unorganized North Cochrane District</e>\n<e>Unorganized Kenora District</e> || northeast || <e>"\'\'"</e>\n<e>Unorganized Kenora Dis
# ...
